# %% [markdown]
# ##Link to colab: https://colab.research.google.com/drive/1DYUxxZOQUIqxkYpHqUGmb7OVQlEQwBka?usp=sharing

# %% [markdown]
# You are a product manager for a company that has recently launched a new product.
# Customer satisfaction is a critical metric, and you want to determine if the proportion of satisfied customers with the new product meets your target satisfaction level of 70%.
# You collected a random sample of 150 customer reviews, and 115 of them expressed satisfaction with the product.![Screenshot 2024-03-08 at 10.57.03 PM.png](data:image/png;base64,...)

# %%
import numpy as np
import scipy.stats as stats

# %%
satisfied_customers = 115
total_customers = 150
target_satisfaction = 0.70

# %% [markdown]
# - Ho:  p = p_hat
# - Ha: p < p_hat

# %%
p = target_satisfaction

# %%
p_hat = satisfied_customers / total_customers

# %%
p_hat
# Out:
# 0.7666666666666667

# %%
n = total_customers

# %%
z_st = (p_hat - p) / np.sqrt((p * (1 - p)) / n)

# %%
print(z_st)
# Out:
# 1.7817416127494983

# %%
p_value = 2 * ( 1- stats.norm.cdf(np.abs(z_st)))
print(p_value)
# Out:
# 0.07479137758694376

# %%
# Print the results
print(f"Z-statistic = {z_st}")
print(f"P-value = {p_value}")
# Out:
# Z-statistic = 1.7817416127494983
# P-value = 0.07479137758694376

# %%
alpha = 0.05  # Significance level
if p_value < alpha:
    decision = "Reject the null hypothesis"
else:
    decision = "Fail to reject the null hypothesis"

if decision == "Reject the null hypothesis":
    conclusion = "There is enough evidence to conclude that the proportion of satisfied customers with the new product is statistically different from the target satisfaction level."
else:
    conclusion = "There is not enough evidence to conclude that the proportion of satisfied customers with the new product is statistically different from the target satisfaction level."

# Print the results
print(f"Decision: {decision}")
print(f"Conclusion: {conclusion}")
# Out:
# Decision: Fail to reject the null hypothesis
# Conclusion: There is not enough evidence to conclude that the proportion of satisfied customers with the new product is statistically different from the target satisfaction level.

# %% [markdown]
# A researcher is studying the satisfaction level of customers after implementing a new customer service system. They collected survey responses from 250 customers and found that 65 of them were dissatisfied with the new system.
# The researcher wants to test the null hypothesis that no more than 30% of customers are dissatisfied with the new system.
# Use the p-value technique to test the claim with a significance level of α = 0.05.

# %%
n = 250
x = 65
p_hat = x/n
p = 0.30

# %%
z_st = (p_hat - p) / np.sqrt((p * (1 - p)) / n)

print(z_st)
# Out:
# -1.3801311186847078

# %%
p_value = 1 - stats.norm.cdf(z_st)

# %%
print(p_value)
# Out:
# 0.9162268612556912

# %%
# Define the significance level
alpha = 0.05

# Make a decision based on the p-value and significance level
if p_value < alpha:
  print('Reject the null hypothesis.')
else:
  print('Fail to reject the null hypothesis.')
# Out:
# Fail to reject the null hypothesis.

# %% [markdown]
# You are the manager of an e-commerce website, and you have recently implemented a new web page in hopes of increasing sales.
#
# To evaluate the effectiveness of the new page, you collected data on the conversion rates for both the old and new web pages. The conversion rate is defined as the proportion of visitors who make a purchase.
#
# For the old web page (Web Page A), you had 1000 visitors, resulting in 50 conversions.
# For the new web page (Web Page B), you had 500 visitors, resulting in 30 conversions.
# Now, you want to determine if there is a statistically significant difference in the conversion rates between the old and new web pages.

# %%
import statsmodels.api as sm
import numpy as np

# %%
# Define the data
conversions = np.array([50, 30])  # Number of conversions for Web Page A and Web Page B # x_1, x_2
visits = np.array([1000, 500])

# %%
conversions
# Out:
# array([50, 30])

# %%
visits
# Out:
# array([1000,  500])

# %%
z_stat, p_value = sm.stats.proportions_ztest(conversions,
                           visits,
                           alternative='greater')

# %%
# Print the results
print(f"Z-statistic = {z_stat}")
print(f"P-value = {p_value}")
# Out:
# Z-statistic = -0.8125338562826986
# P-value = 0.4164853677823287

# %%
##Scratch code implementation

# %%
# Data for the old web page (Web Page A)
n_1 = 1000 # visits_1
x_1 = 50 # conversions_1

# Data for the new web page (Web Page B)
n_2 = 500 # visits_2
x_2 = 30 # conversions_2

# %%
p_1_hat = x_1 / n_1
p_2_hat = x_2 / n_2

# %%
p_hat = (x_1 + x_2) / (n_1 + n_2)

# %%
Z = (p_1_hat - p_2_hat) / np.sqrt(p_hat * (1 - p_hat) * ((1 / n_1) + (1 / n_2)))

# %%
p_value = 2 * (1 - stats.norm.cdf(np.abs(Z)))

# %%
# Make a decision and conclusion
if p_value < alpha:
    decision = "Reject the null hypothesis"
else:
    decision = "Fail to reject the null hypothesis"

if decision == "Reject the null hypothesis":
    conclusion = "There is enough evidence to conclude that the conversion rates of the new web page (Web Page B) are statistically different from the old web page (Web Page A)."
else:
    conclusion = "There is not enough evidence to conclude that the conversion rates of the new web page (Web Page B) are statistically different from the old web page (Web Page A)."

# Print the results
print(f"Decision: {decision}")
print(f"Conclusion: {conclusion}")
# Out:
# Decision: Fail to reject the null hypothesis
# Conclusion: There is not enough evidence to conclude that the conversion rates of the new web page (Web Page B) are statistically different from the old web page (Web Page A).

# %% [markdown]
# ## T-Test

# %%
data = np.array([110, 105, 98, 102, 99, 104, 115, 95])

# %%
pop_mean = 100

# %%
np.mean(data)
# Out:
# 103.5

# %%
# z_st = (sample_mean - pop_mean) / (pop_std/np.sqrt(n))

# %%
from scipy.stats import ttest_1samp

# %%
t_stat, pvalue = ttest_1samp(data, pop_mean)
t_stat, pvalue
# Out:
# (1.5071573172061195, 0.1754994493585011)

# %%
alpha = 0.01 # 99% confidence

if pvalue < alpha:
  print('Reject H0; Pill has effect')
else:
  print ('Fail to Reject H0; Pill has NO effect')
# Out:
# Fail to Reject H0; Pill has NO effect

# %% [markdown]
# ## Two sample t-test

# %%
# !wget --no-check-certificate https://drive.google.com/uc?id=1qSiKRk_9fNmTWsEDWqOygwcGrU-XuINw -O iq_two_schools.csv
# Out:
# --2024-03-08 17:24:05--  https://drive.google.com/uc?id=1qSiKRk_9fNmTWsEDWqOygwcGrU-XuINw
# Resolving drive.google.com (drive.google.com)... 172.217.15.238, 2607:f8b0:4025:802::200e
# Connecting to drive.google.com (drive.google.com)|172.217.15.238|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://drive.usercontent.google.com/download?id=1qSiKRk_9fNmTWsEDWqOygwcGrU-XuINw [following]
# --2024-03-08 17:24:05--  https://drive.usercontent.google.com/download?id=1qSiKRk_9fNmTWsEDWqOygwcGrU-XuINw
# Resolving drive.usercontent.google.com (drive.usercontent.google.com)... 172.217.15.225, 2607:f8b0:4025:802::2001
# Connecting to drive.usercontent.google.com (drive.usercontent.google.com)|172.217.15.225|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 639 [application/octet-stream]
# Saving to: ‘iq_two_schools.csv’
#
# iq_two_schools.csv  100%[===================>]     639  --.-KB/s    in 0s
#
# ...

# %%
import pandas as pd

df_iq = pd.read_csv('/content/iq_two_schools.csv')
df_iq.head()
# Out:
#      School   iq
# 0  school_1   91
# 1  school_1   95
# 2  school_1  110
# 3  school_1  112
# 4  school_1  115

# %%
df_iq['School'].unique()
# Out:
# array(['school_1', 'school_2'], dtype=object)

# %%
df_iq.groupby('School')['iq'].mean()
# Out:
# School
# school_1    101.153846
# school_2    109.416667
# Name: iq, dtype: float64

# %% [markdown]
# ## Option1: Ha = u1 != u2

# %%
from scipy.stats import ttest_ind

# %%
iq_1 = df_iq[df_iq['School'] == 'school_1']['iq']
iq_2 = df_iq[df_iq['School'] == 'school_2']['iq']

iq_1
# Out:
# 0      91
# 1      95
# 2     110
# 3     112
# 4     115
# 5      94
# 6      82
# 7      84
# 8      85
# 9      89
# 10     91
# 11     91
# 12     92
# 13     94
# 14     99
# 15     99
# 16    105
# 17    109
# 18    109
# 19    109
# 20    110
# 21    112
# 22    112
# 23    113
# 24    114
# 25    114
# Name: iq, dtype: int64

# %%
t_stat, pvalue = ttest_ind(iq_1, iq_2)
t_stat, pvalue
# Out:
# (-2.4056474861512704, 0.02004552710936217)

# %%
alpha = 0.05 # 95% confidence

if pvalue < alpha:
  print('Reject H0')
else:
  print ('Fail to Reject H0')
# Out:
# Reject H0

# %% [markdown]
# ## Option2: Ha => u1 > u2

# %%
t_stat, pvalue = ttest_ind(iq_1, iq_2, alternative = "greater")
t_stat, pvalue
# Out:
# (-2.4056474861512704, 0.9899772364453189)

# %%
alpha = 0.05 # 95% confidence

if pvalue < alpha:
  print('Reject H0')
else:
  print ('Fail to Reject H0')
# Out:
# Fail to Reject H0

# %% [markdown]
# ## ## Option3: Ha => u1 < u2

# %%
t_stat, pvalue = ttest_ind(iq_1, iq_2, alternative = "less")
t_stat, pvalue
# Out:
# (-2.4056474861512704, 0.010022763554681085)

# %%
alpha = 0.05 # 95% confidence

if pvalue < alpha:
  print('Reject H0')
else:
  print ('Fail to Reject H0')
# Out:
# Reject H0

# %%
# !wget --no-check-certificate https://drive.google.com/uc?id=1bvVVbWUu6JKQDol0xwj3pqsTs4Qxm_oj -O Sachin_ODI.csv
# Out:
# --2024-03-08 17:35:48--  https://drive.google.com/uc?id=1bvVVbWUu6JKQDol0xwj3pqsTs4Qxm_oj
# Resolving drive.google.com (drive.google.com)... 172.217.15.238, 2607:f8b0:4025:802::200e
# Connecting to drive.google.com (drive.google.com)|172.217.15.238|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://drive.usercontent.google.com/download?id=1bvVVbWUu6JKQDol0xwj3pqsTs4Qxm_oj [following]
# --2024-03-08 17:35:49--  https://drive.usercontent.google.com/download?id=1bvVVbWUu6JKQDol0xwj3pqsTs4Qxm_oj
# Resolving drive.usercontent.google.com (drive.usercontent.google.com)... 172.217.15.225, 2607:f8b0:4025:802::2001
# Connecting to drive.usercontent.google.com (drive.usercontent.google.com)|172.217.15.225|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 26440 (26K) [application/octet-stream]
# Saving to: ‘Sachin_ODI.csv’
#
# Sachin_ODI.csv      100%[===================>]  25.82K  --.-KB/s    in 0.001s
#
# ...

# %%
df = pd.read_csv('/content/Sachin_ODI.csv')
df
# Out:
#      runs  NotOut mins   bf  fours  sixes      sr  Inns           Opp  \
# 0      13       0   30   15      3      0   86.66     1   New Zealand
# 1      37       0   75   51      3      1   72.54     2  South Africa
# 2      47       0   65   40      7      0  117.50     2     Australia
# 3      48       0   37   30      9      1  160.00     2    Bangladesh
# 4       4       0   13    9      1      0   44.44     2      Pakistan
# ..    ...     ...  ...  ...    ...    ...     ...   ...           ...
# 355    14       0   34   15      2      0   93.33     2     Australia
# 356    39       0   45   30      5      0  130.00     2     Sri Lanka
# 357     6       0   25   19      1      0   31.57     1     Sri Lanka
# 358   114       0  205  147     12      1   77.55     1    Bangladesh
# 359    52       0   93   48      5      1  108.33     2      Pakistan
#
#        Ground        Date        Winner    Won  century
# 0      Napier  1995-02-16   New Zealand  False    False
# ...

# %%
df.groupby('Inns')['runs'].mean()
# Out:
# Inns
# 1    46.670588
# 2    40.173684
# Name: runs, dtype: float64

# %%
df_first_innings = df[df['Inns'] == 1]
df_second_innings = df[df['Inns'] == 2]

# %%
df_first_innings.shape
# Out:
# (170, 14)

# %%
df_second_innings.shape
# Out:
# (190, 14)

# %%
# Ho = u1 = u2
# ha = u1 > u2

# %%
t_stat, pvalue = ttest_ind(df_first_innings['runs'],
                           df_second_innings['runs'],
                           alternative = "greater")
t_stat, pvalue
# Out:
# (1.4612016295532178, 0.07241862097379981)

# %%
alpha = 0.05 # 95% confidence

if pvalue < alpha:
  print('Reject H0')
  print('First innings is better')
else:
  print ('Fail to Reject H0')
  print('Difference we observe is just chance')
# Out:
# Fail to Reject H0
# Difference we observe is just chance

# %%
u1 <> u2

# %%
from scipy.stats import ttest_rel
import pandas as pd

# %%
# !wget --no-check-certificate https://drive.google.com/uc?id=1PZ1cC8nBZEtvnOYjfrg4xyErI-5i_-ae -O problem_solving.csv
# Out:
# --2024-03-08 17:52:30--  https://drive.google.com/uc?id=1PZ1cC8nBZEtvnOYjfrg4xyErI-5i_-ae
# Resolving drive.google.com (drive.google.com)... 172.217.15.238, 2607:f8b0:4025:802::200e
# Connecting to drive.google.com (drive.google.com)|172.217.15.238|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://drive.usercontent.google.com/download?id=1PZ1cC8nBZEtvnOYjfrg4xyErI-5i_-ae [following]
# --2024-03-08 17:52:30--  https://drive.usercontent.google.com/download?id=1PZ1cC8nBZEtvnOYjfrg4xyErI-5i_-ae
# Resolving drive.usercontent.google.com (drive.usercontent.google.com)... 172.217.15.225, 2607:f8b0:4025:802::2001
# Connecting to drive.usercontent.google.com (drive.usercontent.google.com)|172.217.15.225|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1277 (1.2K) [application/octet-stream]
# Saving to: ‘problem_solving.csv’
#
# problem_solving.csv 100%[===================>]   1.25K  --.-KB/s    in 0s
#
# ...

# %%
Path= '/content/problem_solving.csv'
df_ps = pd.read_csv(Path)

# %%
df_ps.head()
# Out:
#    id  test_1  test_2
# 0   0      40      38
# 1   1      49      44
# 2   2      65      69
# 3   3      59      63
# 4   4      44      43

# %%
# H0: Problem-solving has no effect
# Ha: Problem-solving had an effect

# %%
statistic, pvalue = ttest_rel(df_ps["test_1"], df_ps["test_2"])
print("Test statistic:",statistic)
print("pvalue:",pvalue)
# Out:
# Test statistic: -5.502886353508166
# pvalue: 1.795840353792313e-07

# %%
alpha = 0.05 # 95% confidence

if pvalue < alpha:
  print('Reject H0')
else:
  print ('Fail to Reject H0')
# Out:
# Reject H0

# %%
# H0: Problem solving has no effect
# Ha: Problem solving improved the scores

statistic, pvalue = ttest_rel(df_ps["test_1"], df_ps["test_2"],alternative="less")
print("Test statistic:",statistic)
print("pvalue:",pvalue)
# Out:
# Test statistic: -5.502886353508166
# pvalue: 8.979201768961566e-08

# %%
alpha = 0.05 # 95% confidence

if pvalue < alpha:
  print('Reject H0')
else:
  print ('Fail to Reject H0')
# Out:
# Reject H0
